# %% [markdown]
# # Import modules

# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup #Pull data out of HTML and XML.
from selenium import webdriver
import time
import re
import collections
from collections import Counter

# %% [markdown]
# # Scrapping

# %%
'''
 initialisation des variables contenants les liens du site
'''
url_rank_serie = 'https://www.imdb.com/chart/toptv/'
url_imdb_base = 'https://www.imdb.com'
url_serie_ = f'?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=12230b0e-0e00-43ed-9e59-8d5353703cce&pf_rd_r=BFQY8EMES4H7BK35D10R&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=toptv&ref_=chttvtp_tt_'

# %%
def get_html_from_link(page_link):
    '''
        Get HTML from web page and parse it.

        :param page_link: link of the webpage we want to scrap
        :type page_link: string
        :return: BeautifulSoup object (HTML parsed)
        :rtype: bs4.BeautifulSoup
    '''

    response = requests.get(page_link)
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %%
html_all = get_html_from_link(url_rank_serie)

# %%
def get_link_to_serie(root_html):

    """
    This function extract the link to acces the series information page.
    
    :param root_html: BeautifulSoup Element that contains all books links.
    :type book_html: bs4.BeautifulSoup.
    :return: list of all serie links in the page.
    :rtype: list(str).
    """
    serie_links = []
    reg = re.compile('/title/+')
    for elem in root_html.find_all('td', {'class':'titleColumn'}):
        for elements in elem.find_all('a', {'href' : reg}):
            attribut = elements["href"]
            serie_links.append(attribut)
    #len(serie_links)
    return(serie_links)

# %%
serie_links=get_link_to_serie(html_all)
#serie_links

# %%
def get_info_serie(serie_html):
    
    """
    Return series informations
    
    :param serie_html: BeautifulSoup element that contains serie infos.
    :type serie_html: bs4.element.Tag.
    :return:
            - serie_title: tile of the TV serie.
            - serie_genre: genre-s of the TV serie.
            - serie_nb_season:
            - serie_type: the serie can be TV Mini-Series or TV Series.
            - serie_actors : actors who play in the TV serie.
            - serie_creator : creator-s of the TV serie
            - serie_origin: origins/country of the TV serie.
            - serie_language: speaking language of the TV serie.
            - serie_nb_episode:
            - serie_certification : certificate of the TV serie (Tous public, 12, 16...).
            - serie_rating: rating of the TV serie.
    :rtype: tuple(list(str), string, string, list(str), list(str), string)
    """
    
    serie_title = serie_html.find('h1').text.strip()
    
    serie_genre=[]
    reg_search = re.compile('/search/title+')
    for div in serie_html.find_all("div", {"class":"see-more inline canwrap"}):
        for a in div.find_all("a", {"href": reg_search}):
            genre = a.text
            serie_genre.append(genre)
            
            
    nb_season=[]
    reg_season = re.compile('/title/')
    for div in serie_html.find_all("div", {"class":"seasons-and-year-nav"}):
        for c in div.find_all("a", {"href": reg_season}):
                season_not_filtered = c.text
                nb_season.append(season_not_filtered)
                serie_nb_season = ""
                if nb_season != 1:
                        serie_nb_season = nb_season[0]
                        
                        
    serie_nb_episode=serie_html.find('span', {'class':'bp_sub_heading'}).text
    
    
    reg = re.compile('/title/+')
    serie_type = serie_html.find("a", {"href": reg, "title":"See more release dates"}).text
    
    
    serie_actors=[]
    reg_name = re.compile('/name/nm+')
    for div in serie_html.find_all("div", {"class":"article", "id":"titleCast"}):
        for a in div.find_all("a", {"href": reg_name}):
            actors = a.text
            if actors != '':
                serie_actors.append(actors)
                
                
    serie_creators=[]
    for div in serie_html.find_all("div", {"class":"credit_summary_item"}):
        creators = ""
        if div.find("h4", {"class":"inline"}).text == "Creator:":
            for c in div.find_all("a", {"href": reg_name}):
                creators = c.text
                serie_creators.append(creators)
        elif div.find("h4", {"class":"inline"}).text == "Creators:":
            for c in div.find_all("a", {"href": reg_name}):
                creators = c.text
                serie_creators.append(creators)
                
    
    serie_origin=[]
    for div in serie_html.find_all("div", {"class":"txt-block"}):
        for h in div.find_all("h4", {"class":"inline"}):
            country = ""
            if h.text == "Country:":
                for a in div.find_all("a", {"href": reg_search}):
                    country = a.text
                    serie_origin.append(country)
    
    serie_language = ""
    for div in serie_html.find_all("div", {"class":"txt-block"}):
        for h in div.find_all("h4", {"class":"inline"}):
            if h.text == "Language:":
                for a in div.find_all("a", {"href": reg_search}):
                    serie_language = a.text
                    
                    
    
    certif =[]
    serie_certification = ""
    certificate_not_filtered = ""
    for div in serie_html.find_all("div", {"class":"txt-block"}):
        for h in div.find_all("h4", {"class":"inline"}):
            if h.text == "Certificate:":
                for s in div.find_all("span"):
                    certificate_not_filtered = s.text
                    certif.append(certificate_not_filtered)
                    if len(certif) != 1:
                        serie_certification = certif[0]
                        
                        
    serie_rating = serie_html.find('span', {'itemprop':'ratingValue'}).text
                        
    
    return(serie_title, serie_genre, serie_nb_season, serie_nb_episode, serie_type, serie_actors, serie_creators, serie_origin, serie_language, serie_certification,  serie_rating)

# %% [markdown]
# Loop on the first 100 serie links to get informations.
#
# The list start at rank 0 : the first film with classement rank 1 on IMDb starts at rank 0 in the list. The classement rank is set at n + 1 (0 + 1).

# %%
'''
      creation d'une liste avec les séries classées par rang
'''

# %%time
serie_details = []

#Initiate the rank number.
rank_number = 0

for n in range(len(serie_links)-150):
    
    rank_number = n + 1
    # Add rank_number at the en of the url.
    url_serie_rank = url_serie_ + str(rank_number)
    
    # Get the entire url of the page that contains serie informations.
    link_serie = url_imdb_base + serie_links[n] + url_serie_rank
    #print(link_serie) 
    
    html = get_html_from_link(link_serie)
    
    # Apply get_info_serie function to return every link informations.
    info = get_info_serie(html)
    # Add rank.
    info = (rank_number,) + info
    
    # Info contains tuples : add them to a list.
    serie_details.append(info)
    print(rank_number)
    #print(serie_details)
    
print(serie_details)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-3-397705c20307> in get_html_from_link(page_link)
#       9     '''
#      10
# ---> 11     response = requests.get(page_link)
#      12     soup = BeautifulSoup(response.text, 'html.parser')
#      13     return soup
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     342             ca_cert_dir=self.ca_cert_dir,
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#     346         if self.assert_fingerprint:
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     343             or IS_SECURETRANSPORT):
#     344         if HAS_SNI and server_hostname is not None:
# --> 345             return context.wrap_socket(sock, server_hostname=server_hostname)
#     346
#     347         warnings.warn(
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     454         while True:
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#     458                 if not util.wait_for_read(sock, sock.gettimeout()):
#
# /opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1931         :return: None.
#    1932         """
# -> 1933         result = _lib.SSL_do_handshake(self._ssl)
#    1934         self._raise_ssl_error(self._ssl, result)
#    1935
#
# KeyboardInterrupt:

# %%
url_test = url_imdb_base + serie_links[3] + url_serie_ + str(4)
#print(url_test)
cast = get_html_from_link(url_test)
#print(type(cast))

serie_language = ""
for div in cast.find_all("div", {"class":"txt-block"}):
    
    for h in div.find_all("h4", {"class":"inline"}):
            
        if h.text == "Language:":
            for a in div.find_all("a", {"href": reg_search}):
                serie_language = a.text
serie_language
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-152-35072a4fece2> in <module>
#      10
#      11         if h.text == "Language:":
# ---> 12             for a in div.find_all("a", {"href": reg_search}):
#      13                 serie_language = a.text
#      14 serie_language
#
# NameError: name 'reg_search' is not defined

# %% [markdown]
# ## Put de data into a dataframe.

# %% [markdown]
# Put the data from the list of tuple into a dataframe df_serie.
# Then, export the dataframe to a csv file to save it.

# %%
df_serie = pd.DataFrame(serie_details, 
                        columns = ["Rank", "Title", "Genre", "Number_of_season", "Number_of_episodes", "Type", "Actors", 
                                   "Creators", "Origin", "Language", "Certification", "Rating"])

df_serie.to_csv('C:\\Users\\stosc\\Documents\\ESME\\Ingé2_2019-2020\\S2\\UE1\\DataTools\\Projet\series_data.csv', 
                index=False, header=True)

df_serie
# Out:
#    Rank                        Title                              Genre  \
# 0     1              Planet Earth II                     [ Documentary]
# 1     2                 Planet Earth                     [ Documentary]
# 2     3             Band of Brothers  [ Action,  Drama,  History,  War]
# 3     4                 Breaking Bad        [ Crime,  Drama,  Thriller]
# 4     5                    Chernobyl      [ Drama,  History,  Thriller]
# 5     6                     The Wire        [ Crime,  Drama,  Thriller]
# 6     7               Blue Planet II                     [ Documentary]
# 7     8                   Our Planet                     [ Documentary]
# 8     9  Cosmos: A Spacetime Odyssey                     [ Documentary]
#
#   Number_of_season Number_of_episodes                          Type  \
# 0                1         6 episodes       TV Mini-Series (2016)\n
# 1                1        11 episodes       TV Mini-Series (2006)\n
# 2                1        10 episodes       TV Mini-Series (2001)\n
# 3                5        62 episodes       TV Series (2008–2013)\n
# 4                1         5 episodes       TV Mini-Series (2019)\n
# 5                5        60 episodes       TV Series (2002–2008)\n
# 6                1         8 episodes  TV Mini-Series (2017–2018)\n
# 7                1         8 episodes       TV Mini-Series (2019)\n
# 8                1        13 episodes            TV Series (2014)\n
#
#                                               Actors          Creators  \
# 0                            [ David Attenborough\n]                []
# 1  [ David Attenborough\n,  Sigourney Weaver\n,  ...                []
# 2  [ Scott Grimes\n,  Damian Lewis\n,  Ron Living...                []
# 3  [ Bryan Cranston\n,  Anna Gunn\n,  Aaron Paul\...  [Vince Gilligan]
# 4  [ Jessie Buckley\n,  Jared Harris\n,  Stellan ...     [Craig Mazin]
# 5  [ Dominic West\n,  John Doman\n,  Deirdre Love...     [David Simon]
# 6            [ David Attenborough\n,  Peter Drost\n]                []
# 7                            [ David Attenborough\n]                []
# 8                           [ Neil deGrasse Tyson\n]                []
#
#       Origin    Language Certification Rating
# 0       [UK]     English                  9.5
# 1       [UK]     English                  9.4
# 2  [USA, UK]  Lithuanian                  9.4
# 3      [USA]     Spanish                  9.5
# 4  [USA, UK]     English                  9.4
# 5      [USA]     Spanish                  9.3
# 6       [UK]     English                  9.3
# 7  [USA, UK]     English                  9.3
# 8      [USA]     English                  9.3

# %%
# Read the csv file into a dataframe.
df_serie = pd.read_csv("C:\\Users\\stosc\\Documents\\ESME\\Ingé2_2019-2020\\S2\\UE1\\DataTools\\Projet\series_data.csv",
                      header=0, index_col=0)

# %%
df_serie['Creators'] = df_top_ten['Creators'].replace('[]', "Nan")
df_serie['Origin'] = df_top_ten['Origin'].replace('[]', "Nan")

df_serie.head(50)
# Out:
#                                         Title  \
# Rank
# 1                             Planet Earth II
# 2                               Planète Terre
# 3                              Frères d'armes
# 4                                Breaking Bad
# 5                                   Chernobyl
# 6                                  Sur écoute
# 7                              Blue Planet II
# 8                               Notre planète
# 9     Cosmos: Une odyssée à travers l'univers
# 10                            Game of Thrones
# 11                                     Cosmos
# 12                             The Last Dance
# 13                              Rick et Morty
# 14         Avatar, le dernier maître de l'air
# 15                                Les Soprano
# 16                           The World at War
# 17                 Life, l'aventure de la vie
# 18           Fullmetal Alchemist: Brotherhood
# 19                                   Sherlock
# 20                            The Vietnam War
# 21                     La quatrième dimension
# 22                                   Sahsiyet
# 23                      The Beatles Anthology
# 24                         Planète des hommes
# 25                            The Blue Planet
# 26                                     Batman
# 27                            Terres de glace
# 28                                    Firefly
# 29                               Le décalogue
# 30                             True Detective
# 31                              The Civil War
# 32                                 Death Note
# 33        Apocalypse: La 2ème guerre mondiale
# 34                                      Fargo
# 35                               Cowboy Bebop
# 36                            Afrique sauvage
# 37                           Dans leur regard
# 38                                    Ramayan
# 39         Last Week Tonight with John Oliver
# 40                               TVF Pitchers
# 41                            Hunter x Hunter
# 42                  Only Fools and Horses....
# 43                                 The Office
# 44                                    Friends
# 45                                  Le bateau
# 46               Monty Python's Flying Circus
# 47                                   Seinfeld
# 48                 Souvenirs de Gravity Falls
# 49                        Orgueil et préjugés
# 50                     How the Universe Works
#
#                                                   Genre  Number_of_season  \
# Rank
# 1                                      [' Documentary']                 1
# 2                                      [' Documentary']                 1
# 3             [' Action', ' Drama', ' History', ' War']                 1
# 4                     [' Crime', ' Drama', ' Thriller']                 5
# 5                   [' Drama', ' History', ' Thriller']                 1
# 6                     [' Crime', ' Drama', ' Thriller']                 5
# 7                                      [' Documentary']                 1
# 8                                      [' Documentary']                 1
# 9                                      [' Documentary']                 1
# 10    [' Action', ' Adventure', ' Drama', ' Fantasy'...                 8
# 11                                     [' Documentary']                 1
# 12    [' Documentary', ' Biography', ' History', ' S...                 1
# 13    [' Animation', ' Adventure', ' Comedy', ' Sci-...                 5
# 14    [' Animation', ' Action', ' Adventure', ' Fami...                 3
# 15                                 [' Crime', ' Drama']                 6
# 16                 [' Documentary', ' History', ' War']                 1
# 17                                     [' Documentary']                 1
# 18    [' Animation', ' Action', ' Adventure', ' Come...                 1
# 19        [' Crime', ' Drama', ' Mystery', ' Thriller']                 4
# 20                 [' Documentary', ' History', ' War']                 1
# 21    [' Drama', ' Fantasy', ' Horror', ' Mystery', ...                 5
# 22                     [' Crime', ' Drama', ' Mystery']                 1
# 23                           [' Documentary', ' Music']                 1
# 24                                     [' Documentary']                 1
# 25                                     [' Documentary']                 1
# 26    [' Animation', ' Action', ' Adventure', ' Fami...                 4
# 27                                     [' Documentary']                 1
# 28                  [' Adventure', ' Drama', ' Sci-Fi']                 1
# 29                                           [' Drama']                 1
# 30        [' Crime', ' Drama', ' Mystery', ' Thriller']                 3
# 31                 [' Documentary', ' History', ' War']                 1
# 32    [' Animation', ' Crime', ' Drama', ' Fantasy',...                 1
# 33                 [' Documentary', ' History', ' War']                 1
# 34                    [' Crime', ' Drama', ' Thriller']                 4
# 35    [' Animation', ' Action', ' Adventure', ' Dram...                 1
# 36                                     [' Documentary']                 1
# 37       [' Biography', ' Crime', ' Drama', ' History']                 1
# 38                      [' Family', ' Fantasy', ' War']                 1
# 39                   [' Comedy', ' News', ' Talk-Show']                 7
# 40                                [' Comedy', ' Drama']                 1
# 41    [' Animation', ' Action', ' Adventure', ' Come...                 1
# 42                                          [' Comedy']                 9
# 43                                          [' Comedy']                 9
# 44                              [' Comedy', ' Romance']                10
# 45                      [' Drama', ' Thriller', ' War']                 1
# 46                                          [' Comedy']                 4
# 47                                          [' Comedy']                 9
# 48    [' Animation', ' Action', ' Adventure', ' Come...                 2
# 49                               [' Drama', ' Romance']                 1
# 50                                     [' Documentary']                 8
#
#      Number_of_episodes                          Type  \
# Rank
# 1            6 episodes       TV Mini-Series (2016)\n
# 2           11 episodes       TV Mini-Series (2006)\n
# 3           10 episodes       TV Mini-Series (2001)\n
# 4           62 episodes       TV Series (2008–2013)\n
# 5            5 episodes       TV Mini-Series (2019)\n
# 6           60 episodes       TV Series (2002–2008)\n
# 7            8 episodes  TV Mini-Series (2017–2018)\n
# 8            8 episodes       TV Mini-Series (2019)\n
# 9           13 episodes            TV Series (2014)\n
# 10          73 episodes       TV Series (2011–2019)\n
# 11          13 episodes            TV Series (1980)\n
# 12          10 episodes       TV Mini-Series (2020)\n
# 13          42 episodes          TV Series (2013– )\n
# 14          66 episodes       TV Series (2005–2008)\n
# 15          86 episodes       TV Series (1999–2007)\n
# 16          26 episodes       TV Series (1973–1976)\n
# 17          11 episodes       TV Mini-Series (2009)\n
# 18          69 episodes       TV Series (2009–2012)\n
# 19          15 episodes       TV Series (2010–2017)\n
# 20          10 episodes       TV Mini-Series (2017)\n
# 21         156 episodes       TV Series (1959–1964)\n
# 22          12 episodes       TV Mini-Series (2018)\n
# 23           8 episodes  TV Mini-Series (1995–1996)\n
# 24           8 episodes       TV Mini-Series (2011)\n
# 25          10 episodes            TV Series (2001)\n
# 26          85 episodes       TV Series (1992–1995)\n
# 27          10 episodes  TV Mini-Series (2011–2012)\n
# 28          14 episodes       TV Series (2002–2003)\n
# 29          10 episodes  TV Mini-Series (1989–1990)\n
# 30          24 episodes          TV Series (2014– )\n
# 31           9 episodes       TV Mini-Series (1990)\n
# 32          37 episodes       TV Series (2006–2007)\n
# 33           6 episodes       TV Mini-Series (2009)\n
# 34          40 episodes          TV Series (2014– )\n
# 35          26 episodes       TV Series (1998–1999)\n
# 36           7 episodes       TV Mini-Series (2013)\n
# 37           4 episodes       TV Mini-Series (2019)\n
# 38          78 episodes       TV Series (1987–1988)\n
# 39         196 episodes          TV Series (2014– )\n
# 40           5 episodes       TV Mini-Series (2015)\n
# 41         148 episodes       TV Series (2011–2014)\n
# 42          64 episodes       TV Series (1981–2003)\n
# 43         188 episodes       TV Series (2005–2013)\n
# 44         235 episodes       TV Series (1994–2004)\n
# 45           3 episodes  TV Mini-Series (1985–1987)\n
# 46          45 episodes       TV Series (1969–1974)\n
# 47         172 episodes       TV Series (1989–1998)\n
# 48          40 episodes       TV Series (2012–2016)\n
# 49           6 episodes       TV Mini-Series (1995)\n
# 50          77 episodes          TV Series (2010– )\n
#
#                                                  Actors  \
# Rank
# 1                             [' David Attenborough\n']
# 2     [' David Attenborough\n', ' Sigourney Weaver\n...
# 3     [' Scott Grimes\n', ' Damian Lewis\n', ' Ron L...
# 4     [' Bryan Cranston\n', ' Anna Gunn\n', ' Aaron ...
# 5     [' Jessie Buckley\n', ' Jared Harris\n', ' Ste...
# 6     [' Dominic West\n', ' John Doman\n', ' Deirdre...
# 7           [' David Attenborough\n', ' Peter Drost\n']
# 8                             [' David Attenborough\n']
# 9                            [' Neil deGrasse Tyson\n']
# 10    [' Peter Dinklage\n', ' Lena Headey\n', ' Emil...
# 11    [' Carl Sagan\n', ' Jaromír Hanzlík\n', ' Jona...
# 12    [' Phil Jackson\n', ' Michael Jordan\n', ' Dav...
# 13    [' Justin Roiland\n', ' Chris Parnell\n', ' Sp...
# 14    [' Zach Tyler\n', ' Jack De Sena\n', ' Dee Bra...
# 15    [' James Gandolfini\n', ' Lorraine Bracco\n', ...
# 16                              [' Laurence Olivier\n']
# 17        [' Oprah Winfrey\n', ' David Attenborough\n']
# 18    [' Kent Williams\n', ' Iemasa Kayumi\n', ' Vic...
# 19    [' Benedict Cumberbatch\n', ' Martin Freeman\n...
# 20    [' Peter Coyote\n', ' Huy Duc\n', ' James Will...
# 21                                   [' Rod Serling\n']
# 22    [' Haluk Bilginer\n', ' Cansu Dere\n', ' Metin...
# 23    [' Paul McCartney\n', ' George Harrison\n', ' ...
# 24                                     [' John Hurt\n']
# 25       [' David Attenborough\n', ' Pierce Brosnan\n']
# 26    [' Kevin Conroy\n', ' Efrem Zimbalist Jr.\n', ...
# 27         [' David Attenborough\n', ' Alec Baldwin\n']
# 28    [' Nathan Fillion\n', ' Gina Torres\n', ' Alan...
# 29    [' Artur Barcis\n', ' Olgierd Lukaszewicz\n', ...
# 30    [' Matthew McConaughey\n', ' Colin Farrell\n',...
# 31    [' Sam Waterston\n', ' Julie Harris\n', ' Jaso...
# 32    [' Mamoru Miyano\n', ' Brad Swaile\n', ' Vince...
# 33          [' Mathieu Kassovitz\n', ' Martin Sheen\n']
# 34    [' Allison Tolman\n', ' Billy Bob Thornton\n',...
# 35    [' Kôichi Yamadera\n', ' Unshô Ishizuka\n', ' ...
# 36       [' David Attenborough\n', ' Simon Blakeney\n']
# 37    [' Asante Blackk\n', ' Caleel Harris\n', ' Eth...
# 38    [' Arun Govil\n', ' Deepika Chikhalia\n', ' Su...
# 39                  [' John Oliver\n', ' David Kaye\n']
# 40    [' Naveen Kasturia\n', ' Arunabh Kumar\n', ' J...
# 41    [' Issei Futamata\n', ' Megumi Han\n', ' Crist...
# 42    [' David Jason\n', ' Nicholas Lyndhurst\n', ' ...
# 43    [' Rainn Wilson\n', ' John Krasinski\n', ' Jen...
# 44    [' Jennifer Aniston\n', ' Courteney Cox\n', ' ...
# 45    [' Jürgen Prochnow\n', ' Herbert Grönemeyer\n'...
# 46    [' Graham Chapman\n', ' Eric Idle\n', ' Terry ...
# 47    [' Jerry Seinfeld\n', ' Jason Alexander\n', ' ...
# 48    [' Jason Ritter\n', ' Alex Hirsch\n', ' Kriste...
# 49    [' Jennifer Ehle\n', ' Colin Firth\n', ' Susan...
# 50    [' Phil Plait\n', ' Michelle Thaller\n', ' Mik...
#
#                              Creators         Origin    Language  \
# Rank
# 1                                 Nan         ['UK']     English
# 2                                 Nan         ['UK']     English
# 3                                 Nan  ['USA', 'UK']  Lithuanian
# 4                  ['Vince Gilligan']        ['USA']     Spanish
# 5                     ['Craig Mazin']  ['USA', 'UK']     English
# 6                     ['David Simon']        ['USA']     Spanish
# 7                                 Nan         ['UK']     English
# 8                                 Nan  ['USA', 'UK']     English
# 9                                 Nan        ['USA']     English
# 10    ['David Benioff', 'D.B. Weiss']  ['USA', 'UK']     English
# 11                                NaN            NaN     English
# 12                                NaN            NaN     English
# 13                                NaN            NaN     English
# 14                                NaN            NaN     English
# 15                                NaN            NaN     Russian
# 16                                NaN            NaN    Japanese
# 17                                NaN            NaN     English
# 18                                NaN            NaN    Japanese
# 19                                NaN            NaN     English
# 20                                NaN            NaN         NaN
# 21                                NaN            NaN     English
# 22                                NaN            NaN     Turkish
# 23                                NaN            NaN      French
# 24                                NaN            NaN     English
# 25                                NaN            NaN     English
# 26                                NaN            NaN     English
# 27                                NaN            NaN     Russian
# 28                                NaN            NaN    Mandarin
# 29                                NaN            NaN      Polish
# 30                                NaN            NaN     English
# 31                                NaN            NaN     English
# 32                                NaN            NaN    Japanese
# 33                                NaN            NaN      French
# 34                                NaN            NaN      Hebrew
# 35                                NaN            NaN     English
# 36                                NaN            NaN     English
# 37                                NaN            NaN     English
# 38                                NaN            NaN       Hindi
# 39                                NaN            NaN     English
# 40                                NaN            NaN     English
# 41                                NaN            NaN    Japanese
# 42                                NaN            NaN     English
# 43                                NaN            NaN     English
# 44                                NaN            NaN      French
# 45                                NaN            NaN      German
# 46                                NaN            NaN     Spanish
# 47                                NaN            NaN     English
# 48                                NaN            NaN     English
# 49                                NaN            NaN     English
# 50                                NaN            NaN     English
#
#      Certification  Rating
# Rank
# 1              NaN     9.5
# 2     Tous publics     9.4
# 3     Tous publics     9.4
# 4     Tous publics     9.5
# 5               12     9.4
# 6     Tous publics     9.3
# 7              NaN     9.3
# 8                7     9.3
# 9     Tous publics     9.3
# 10              12     9.3
# 11             NaN     9.3
# 12               7     9.2
# 13              12     9.2
# 14               T     9.2
# 15    Tous publics     9.2
# 16             NaN     9.2
# 17    Tous publics     9.1
# 18    Tous publics     9.1
# 19    Tous publics     9.1
# 20             NaN     9.1
# 21    Tous publics     9.0
# 22             NaN     9.1
# 23             NaN     9.1
# 24             NaN     9.0
# 25             NaN     9.0
# 26    Tous publics     9.0
# 27             NaN     9.0
# 28    Tous publics     9.0
# 29             NaN     9.0
# 30              12     9.0
# 31             NaN     9.0
# 32              10     9.0
# 33             NaN     9.0
# 34    Tous publics     8.9
# 35             NaN     8.9
# 36             NaN     9.0
# 37             NaN     8.9
# 38             NaN     9.3
# 39              10     8.9
# 40             NaN     9.2
# 41    Tous publics     8.9
# 42             NaN     8.9
# 43              13     8.9
# 44    Tous publics     8.9
# 45             NaN     8.8
# 46             NaN     8.8
# 47    Tous publics     8.8
# 48    Tous publics     8.9
# 49             NaN     8.8
# 50             NaN     8.9

# %%
df_top_ten = pd.DataFrame(df_serie.iloc[0:10,:])
df_serie.head(50)
# Out:
#                                         Title  \
# Rank
# 1                             Planet Earth II
# 2                               Planète Terre
# 3                              Frères d'armes
# 4                                Breaking Bad
# 5                                   Chernobyl
# 6                                  Sur écoute
# 7                              Blue Planet II
# 8                               Notre planète
# 9     Cosmos: Une odyssée à travers l'univers
# 10                            Game of Thrones
# 11                                     Cosmos
# 12                             The Last Dance
# 13                              Rick et Morty
# 14         Avatar, le dernier maître de l'air
# 15                                Les Soprano
# 16                           The World at War
# 17                 Life, l'aventure de la vie
# 18           Fullmetal Alchemist: Brotherhood
# 19                                   Sherlock
# 20                            The Vietnam War
# 21                     La quatrième dimension
# 22                                   Sahsiyet
# 23                      The Beatles Anthology
# 24                         Planète des hommes
# 25                            The Blue Planet
# 26                                     Batman
# 27                            Terres de glace
# 28                                    Firefly
# 29                               Le décalogue
# 30                             True Detective
# 31                              The Civil War
# 32                                 Death Note
# 33        Apocalypse: La 2ème guerre mondiale
# 34                                      Fargo
# 35                               Cowboy Bebop
# 36                            Afrique sauvage
# 37                           Dans leur regard
# 38                                    Ramayan
# 39         Last Week Tonight with John Oliver
# 40                               TVF Pitchers
# 41                            Hunter x Hunter
# 42                  Only Fools and Horses....
# 43                                 The Office
# 44                                    Friends
# 45                                  Le bateau
# 46               Monty Python's Flying Circus
# 47                                   Seinfeld
# 48                 Souvenirs de Gravity Falls
# 49                        Orgueil et préjugés
# 50                     How the Universe Works
#
#                                                   Genre  Number_of_season  \
# Rank
# 1                                      [' Documentary']                 1
# 2                                      [' Documentary']                 1
# 3             [' Action', ' Drama', ' History', ' War']                 1
# 4                     [' Crime', ' Drama', ' Thriller']                 5
# 5                   [' Drama', ' History', ' Thriller']                 1
# 6                     [' Crime', ' Drama', ' Thriller']                 5
# 7                                      [' Documentary']                 1
# 8                                      [' Documentary']                 1
# 9                                      [' Documentary']                 1
# 10    [' Action', ' Adventure', ' Drama', ' Fantasy'...                 8
# 11                                     [' Documentary']                 1
# 12    [' Documentary', ' Biography', ' History', ' S...                 1
# 13    [' Animation', ' Adventure', ' Comedy', ' Sci-...                 5
# 14    [' Animation', ' Action', ' Adventure', ' Fami...                 3
# 15                                 [' Crime', ' Drama']                 6
# 16                 [' Documentary', ' History', ' War']                 1
# 17                                     [' Documentary']                 1
# 18    [' Animation', ' Action', ' Adventure', ' Come...                 1
# 19        [' Crime', ' Drama', ' Mystery', ' Thriller']                 4
# 20                 [' Documentary', ' History', ' War']                 1
# 21    [' Drama', ' Fantasy', ' Horror', ' Mystery', ...                 5
# 22                     [' Crime', ' Drama', ' Mystery']                 1
# 23                           [' Documentary', ' Music']                 1
# 24                                     [' Documentary']                 1
# 25                                     [' Documentary']                 1
# 26    [' Animation', ' Action', ' Adventure', ' Fami...                 4
# 27                                     [' Documentary']                 1
# 28                  [' Adventure', ' Drama', ' Sci-Fi']                 1
# 29                                           [' Drama']                 1
# 30        [' Crime', ' Drama', ' Mystery', ' Thriller']                 3
# 31                 [' Documentary', ' History', ' War']                 1
# 32    [' Animation', ' Crime', ' Drama', ' Fantasy',...                 1
# 33                 [' Documentary', ' History', ' War']                 1
# 34                    [' Crime', ' Drama', ' Thriller']                 4
# 35    [' Animation', ' Action', ' Adventure', ' Dram...                 1
# 36                                     [' Documentary']                 1
# 37       [' Biography', ' Crime', ' Drama', ' History']                 1
# 38                      [' Family', ' Fantasy', ' War']                 1
# 39                   [' Comedy', ' News', ' Talk-Show']                 7
# 40                                [' Comedy', ' Drama']                 1
# 41    [' Animation', ' Action', ' Adventure', ' Come...                 1
# 42                                          [' Comedy']                 9
# 43                                          [' Comedy']                 9
# 44                              [' Comedy', ' Romance']                10
# 45                      [' Drama', ' Thriller', ' War']                 1
# 46                                          [' Comedy']                 4
# 47                                          [' Comedy']                 9
# 48    [' Animation', ' Action', ' Adventure', ' Come...                 2
# 49                               [' Drama', ' Romance']                 1
# 50                                     [' Documentary']                 8
#
#      Number_of_episodes                          Type  \
# Rank
# 1            6 episodes       TV Mini-Series (2016)\n
# 2           11 episodes       TV Mini-Series (2006)\n
# 3           10 episodes       TV Mini-Series (2001)\n
# 4           62 episodes       TV Series (2008–2013)\n
# 5            5 episodes       TV Mini-Series (2019)\n
# 6           60 episodes       TV Series (2002–2008)\n
# 7            8 episodes  TV Mini-Series (2017–2018)\n
# 8            8 episodes       TV Mini-Series (2019)\n
# 9           13 episodes            TV Series (2014)\n
# 10          73 episodes       TV Series (2011–2019)\n
# 11          13 episodes            TV Series (1980)\n
# 12          10 episodes       TV Mini-Series (2020)\n
# 13          42 episodes          TV Series (2013– )\n
# 14          66 episodes       TV Series (2005–2008)\n
# 15          86 episodes       TV Series (1999–2007)\n
# 16          26 episodes       TV Series (1973–1976)\n
# 17          11 episodes       TV Mini-Series (2009)\n
# 18          69 episodes       TV Series (2009–2012)\n
# 19          15 episodes       TV Series (2010–2017)\n
# 20          10 episodes       TV Mini-Series (2017)\n
# 21         156 episodes       TV Series (1959–1964)\n
# 22          12 episodes       TV Mini-Series (2018)\n
# 23           8 episodes  TV Mini-Series (1995–1996)\n
# 24           8 episodes       TV Mini-Series (2011)\n
# 25          10 episodes            TV Series (2001)\n
# 26          85 episodes       TV Series (1992–1995)\n
# 27          10 episodes  TV Mini-Series (2011–2012)\n
# 28          14 episodes       TV Series (2002–2003)\n
# 29          10 episodes  TV Mini-Series (1989–1990)\n
# 30          24 episodes          TV Series (2014– )\n
# 31           9 episodes       TV Mini-Series (1990)\n
# 32          37 episodes       TV Series (2006–2007)\n
# 33           6 episodes       TV Mini-Series (2009)\n
# 34          40 episodes          TV Series (2014– )\n
# 35          26 episodes       TV Series (1998–1999)\n
# 36           7 episodes       TV Mini-Series (2013)\n
# 37           4 episodes       TV Mini-Series (2019)\n
# 38          78 episodes       TV Series (1987–1988)\n
# 39         196 episodes          TV Series (2014– )\n
# 40           5 episodes       TV Mini-Series (2015)\n
# 41         148 episodes       TV Series (2011–2014)\n
# 42          64 episodes       TV Series (1981–2003)\n
# 43         188 episodes       TV Series (2005–2013)\n
# 44         235 episodes       TV Series (1994–2004)\n
# 45           3 episodes  TV Mini-Series (1985–1987)\n
# 46          45 episodes       TV Series (1969–1974)\n
# 47         172 episodes       TV Series (1989–1998)\n
# 48          40 episodes       TV Series (2012–2016)\n
# 49           6 episodes       TV Mini-Series (1995)\n
# 50          77 episodes          TV Series (2010– )\n
#
#                                                  Actors  \
# Rank
# 1                             [' David Attenborough\n']
# 2     [' David Attenborough\n', ' Sigourney Weaver\n...
# 3     [' Scott Grimes\n', ' Damian Lewis\n', ' Ron L...
# 4     [' Bryan Cranston\n', ' Anna Gunn\n', ' Aaron ...
# 5     [' Jessie Buckley\n', ' Jared Harris\n', ' Ste...
# 6     [' Dominic West\n', ' John Doman\n', ' Deirdre...
# 7           [' David Attenborough\n', ' Peter Drost\n']
# 8                             [' David Attenborough\n']
# 9                            [' Neil deGrasse Tyson\n']
# 10    [' Peter Dinklage\n', ' Lena Headey\n', ' Emil...
# 11    [' Carl Sagan\n', ' Jaromír Hanzlík\n', ' Jona...
# 12    [' Phil Jackson\n', ' Michael Jordan\n', ' Dav...
# 13    [' Justin Roiland\n', ' Chris Parnell\n', ' Sp...
# 14    [' Zach Tyler\n', ' Jack De Sena\n', ' Dee Bra...
# 15    [' James Gandolfini\n', ' Lorraine Bracco\n', ...
# 16                              [' Laurence Olivier\n']
# 17        [' Oprah Winfrey\n', ' David Attenborough\n']
# 18    [' Kent Williams\n', ' Iemasa Kayumi\n', ' Vic...
# 19    [' Benedict Cumberbatch\n', ' Martin Freeman\n...
# 20    [' Peter Coyote\n', ' Huy Duc\n', ' James Will...
# 21                                   [' Rod Serling\n']
# 22    [' Haluk Bilginer\n', ' Cansu Dere\n', ' Metin...
# 23    [' Paul McCartney\n', ' George Harrison\n', ' ...
# 24                                     [' John Hurt\n']
# 25       [' David Attenborough\n', ' Pierce Brosnan\n']
# 26    [' Kevin Conroy\n', ' Efrem Zimbalist Jr.\n', ...
# 27         [' David Attenborough\n', ' Alec Baldwin\n']
# 28    [' Nathan Fillion\n', ' Gina Torres\n', ' Alan...
# 29    [' Artur Barcis\n', ' Olgierd Lukaszewicz\n', ...
# 30    [' Matthew McConaughey\n', ' Colin Farrell\n',...
# 31    [' Sam Waterston\n', ' Julie Harris\n', ' Jaso...
# 32    [' Mamoru Miyano\n', ' Brad Swaile\n', ' Vince...
# 33          [' Mathieu Kassovitz\n', ' Martin Sheen\n']
# 34    [' Allison Tolman\n', ' Billy Bob Thornton\n',...
# 35    [' Kôichi Yamadera\n', ' Unshô Ishizuka\n', ' ...
# 36       [' David Attenborough\n', ' Simon Blakeney\n']
# 37    [' Asante Blackk\n', ' Caleel Harris\n', ' Eth...
# 38    [' Arun Govil\n', ' Deepika Chikhalia\n', ' Su...
# 39                  [' John Oliver\n', ' David Kaye\n']
# 40    [' Naveen Kasturia\n', ' Arunabh Kumar\n', ' J...
# 41    [' Issei Futamata\n', ' Megumi Han\n', ' Crist...
# 42    [' David Jason\n', ' Nicholas Lyndhurst\n', ' ...
# 43    [' Rainn Wilson\n', ' John Krasinski\n', ' Jen...
# 44    [' Jennifer Aniston\n', ' Courteney Cox\n', ' ...
# 45    [' Jürgen Prochnow\n', ' Herbert Grönemeyer\n'...
# 46    [' Graham Chapman\n', ' Eric Idle\n', ' Terry ...
# 47    [' Jerry Seinfeld\n', ' Jason Alexander\n', ' ...
# 48    [' Jason Ritter\n', ' Alex Hirsch\n', ' Kriste...
# 49    [' Jennifer Ehle\n', ' Colin Firth\n', ' Susan...
# 50    [' Phil Plait\n', ' Michelle Thaller\n', ' Mik...
#
#                              Creators         Origin    Language  \
# Rank
# 1                                 Nan         ['UK']     English
# 2                                 Nan         ['UK']     English
# 3                                 Nan  ['USA', 'UK']  Lithuanian
# 4                  ['Vince Gilligan']        ['USA']     Spanish
# 5                     ['Craig Mazin']  ['USA', 'UK']     English
# 6                     ['David Simon']        ['USA']     Spanish
# 7                                 Nan         ['UK']     English
# 8                                 Nan  ['USA', 'UK']     English
# 9                                 Nan        ['USA']     English
# 10    ['David Benioff', 'D.B. Weiss']  ['USA', 'UK']     English
# 11                                NaN            NaN     English
# 12                                NaN            NaN     English
# 13                                NaN            NaN     English
# 14                                NaN            NaN     English
# 15                                NaN            NaN     Russian
# 16                                NaN            NaN    Japanese
# 17                                NaN            NaN     English
# 18                                NaN            NaN    Japanese
# 19                                NaN            NaN     English
# 20                                NaN            NaN         NaN
# 21                                NaN            NaN     English
# 22                                NaN            NaN     Turkish
# 23                                NaN            NaN      French
# 24                                NaN            NaN     English
# 25                                NaN            NaN     English
# 26                                NaN            NaN     English
# 27                                NaN            NaN     Russian
# 28                                NaN            NaN    Mandarin
# 29                                NaN            NaN      Polish
# 30                                NaN            NaN     English
# 31                                NaN            NaN     English
# 32                                NaN            NaN    Japanese
# 33                                NaN            NaN      French
# 34                                NaN            NaN      Hebrew
# 35                                NaN            NaN     English
# 36                                NaN            NaN     English
# 37                                NaN            NaN     English
# 38                                NaN            NaN       Hindi
# 39                                NaN            NaN     English
# 40                                NaN            NaN     English
# 41                                NaN            NaN    Japanese
# 42                                NaN            NaN     English
# 43                                NaN            NaN     English
# 44                                NaN            NaN      French
# 45                                NaN            NaN      German
# 46                                NaN            NaN     Spanish
# 47                                NaN            NaN     English
# 48                                NaN            NaN     English
# 49                                NaN            NaN     English
# 50                                NaN            NaN     English
#
#      Certification  Rating
# Rank
# 1              NaN     9.5
# 2     Tous publics     9.4
# 3     Tous publics     9.4
# 4     Tous publics     9.5
# 5               12     9.4
# 6     Tous publics     9.3
# 7              NaN     9.3
# 8                7     9.3
# 9     Tous publics     9.3
# 10              12     9.3
# 11             NaN     9.3
# 12               7     9.2
# 13              12     9.2
# 14               T     9.2
# 15    Tous publics     9.2
# 16             NaN     9.2
# 17    Tous publics     9.1
# 18    Tous publics     9.1
# 19    Tous publics     9.1
# 20             NaN     9.1
# 21    Tous publics     9.0
# 22             NaN     9.1
# 23             NaN     9.1
# 24             NaN     9.0
# 25             NaN     9.0
# 26    Tous publics     9.0
# 27             NaN     9.0
# 28    Tous publics     9.0
# 29             NaN     9.0
# 30              12     9.0
# 31             NaN     9.0
# 32              10     9.0
# 33             NaN     9.0
# 34    Tous publics     8.9
# 35             NaN     8.9
# 36             NaN     9.0
# 37             NaN     8.9
# 38             NaN     9.3
# 39              10     8.9
# 40             NaN     9.2
# 41    Tous publics     8.9
# 42             NaN     8.9
# 43              13     8.9
# 44    Tous publics     8.9
# 45             NaN     8.8
# 46             NaN     8.8
# 47    Tous publics     8.8
# 48    Tous publics     8.9
# 49             NaN     8.8
# 50             NaN     8.9

# %%
'''
    Moyenne du nombre de saison par série
    
 '''

print(df_serie['Number_of_season'].mean())
# Out:
# 3.77

# %%
'''
       Reccupération de la langue la plus utilisée et des occurences des 3 plus communes
'''

print(df_serie['Language'].value_counts().idxmax())
redondant_language=collections.Counter(df_serie['Language']).most_common(3)
print(redondant_language)
# Out:
# English
# [('English', 60), ('Japanese', 9), ('Spanish', 5)]

# %%
'''
       Reccupération du format d'épisode et du type les plus communs
'''
redondant_format=collections.Counter(df_serie['Number_of_episodes']).most_common(3)
print(redondant_format)


redondant_type=collections.Counter(df_serie['Type']).most_common(3)
print(redondant_type)
# Out:
# [('10 episodes', 7), ('6 episodes', 5), ('13 episodes', 5)]
# [('TV Mini-Series (2019)\n', 3), ('TV Series (2013– )\n', 3), ('TV Series (2014– )\n', 3)]

# %%
t = df_serie.iloc[2, 5]
rep = t.replace('[','')
rep = rep.replace(']','')
rep = rep.replace("'","")
rep = rep.replace(",","")

liste = rep.split("\\n")

liste
# Out:
# [' Scott Grimes',
#  '  Damian Lewis',
#  '  Ron Livingston',
#  '  Shane Taylor',
#  '  Donnie Wahlberg',
#  '  Peter Youngblood Hills',
#  '  Matthew Leitch',
#  '  Rod Strohl',
#  '  Nicholas Aaron',
#  '  Philip Barantini',
#  '  Michael Cudlitz',
#  '  Dexter Fletcher',
#  '  Rick Gomez',
#  '  James Madio',
#  '  Ross McCall',
#  '  Doug Allen',
#  '  George Calil',
#  '  Nolan Hemmings',
#  '  Robin Laing',
#  '  Neal McDonough',
#  '  Rick Warden',
#  '  Dale Dye',
#  '  Michael Fassbender',
#  '  Frank John Hughes',
#  '  Tim Matthews',
#  '  Rene L. Moreno',
#  '  Douglas Spain',
#  '  Richard Speight Jr.',
#  '  Kirk Acevedo',
#  '  Eion Bailey',
#  '  Craig Heaney',
#  '  Peter McCabe',
#  '  Matthew Settle',
#  '  Ben Caplan',
#  '  Mark Huberman',
#  '  Phil McKee',
#  '']

# %%
'''
       Reccupération des 10 acteurs les plus cotés sur le top 10
'''
list_actors=[]

for n in range(len(df_serie["Actors"])) :
    clean_column = df_serie.iloc[n, 5]
    clean= clean_column.replace('[','')
    clean = clean.replace(']','')
    clean = clean.replace("'","")
    clean = clean.replace(",","")
    #Split strings element to list : get actors.
    liste = clean.split("\\n")

    for element in liste:
        if element!='':
            list_actors.append(element)
        

#list_actors
redondant_actors=collections.Counter(list_actors).most_common(10)
print(redondant_actors)
# Out:
# [(' David Attenborough', 7), ('  J. Michael Tatum', 3), ('  Christopher Sabat', 3), ('  Kyle Hebert', 3), ('  Mike McFarland', 3), ('  Philip Barantini', 2), ('  Kirk Acevedo', 2), ('  Aaron Paul', 2), ('  Bob Odenkirk', 2), ('  Jonathan Banks', 2)]

# %%
'''
       Reccupération du genre qui marche le mieux 
'''
list_genre=[]

for n in range(len(df_serie["Genre"])) :
    clean_column = df_serie.iloc[n, 1]
    clean= clean_column.replace('[','')
    clean = clean.replace(']','')
    clean = clean.replace("'","")
    clean = clean.replace(",","")
    #Split strings element to list : get actors.
    liste = clean.split("\\n")

    for element in liste:
        if element!='':
            list_genre.append(element)
        

list_genre
redondant_genre=collections.Counter(list_genre).most_common(3)
print(redondant_genre)
# Out:
# [("'", 608), (' ', 508), ('r', 210)]

# %%
print(df_serie.iloc[3, 6])
# Out:
# ['Vince Gilligan']

# %%
list_creators=[]

for n in range(len(df_serie["Creators"])) :
    clean_column = str(df_serie.iloc[n, 6])
    clean= clean_column.replace('[','')
    clean = clean.replace(']','')
    clean = clean.replace("'","")
    clean = clean.replace(",","")
    #Split strings element to list : get actors.
    liste = clean.split("\\n")

    for element in liste:
        if element!='':
            list_creators.append(element)


redondant_creators=collections.Counter(list_creators).most_common(6)
print(redondant_creators)
# Out:
# [('nan', 90), ('Nan', 6), ('Vince Gilligan', 1), ('Craig Mazin', 1), ('David Simon', 1), ('David Benioff D.B. Weiss', 1)]

# %%
list_origin=[]

for n in range(len(df_serie["Origin"])) :
    clean_column = df_serie.iloc[n, 7]
    clean= clean_column.replace('[','')
    clean = clean.replace(']','')
    clean = clean.replace("'","")
    clean = clean.replace(",","")
    #Split strings element to list : get actors.
    liste = clean.split("\\n")

    for element in liste:
        if element!='':
            list_origin.append(element)
        
list_origin

redondant_origin=collections.Counter(list_origin).most_common(2)
print(redondant_origin)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-d4d11a424c17> in <module>
#       3 for n in range(len(df_serie["Origin"])) :
#       4     clean_column = df_serie.iloc[n, 7]
# ----> 5     clean= clean_column.replace('[','')
#       6     clean = clean.replace(']','')
#       7     clean = clean.replace("'","")
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
'''
       Reccupération des certifications 
'''
list_certification=[]

for n in range(len(df_serie["Certification"])) :
    clean_column = str(df_serie.iloc[n, 9])
    clean= clean_column.replace('[','')
    clean = clean.replace(']','')
    clean = clean.replace("'","")
    clean = clean.replace(",","")
    #Split strings element to list : get actors.
    liste = clean.split("\\n")

    for element in liste:
        if element!='':
            if element!='nan':
                list_certification.append(element)
        
list_certification

redondant_certification=collections.Counter(list_certification).most_common(2)
print(redondant_certification)
# Out:
# [('Tous publics', 25), ('12', 8)]
