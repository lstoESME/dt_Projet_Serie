# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, ENGLISH_STOP_WORDS
from sklearn.model_selection import train_test_split
import nltk
import string
from string import digits
nltk.download('stopwords')
import re
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\stosc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Load datas

# %%
# Load stop words from nltk.
nltk_stopwords = set(nltk.corpus.stopwords.words("english")) 

# Load stop words from sklearn.
sklearn_stopwords = set(ENGLISH_STOP_WORDS)

# Load list of non-significative words.
useless = open("C:\\Users\\stosc\\Documents\\ESME\\Ingé2_2019-2020\\S2\\UE1\\Datatools\\Projet\\useless_word.txt", "r")
useless_words = useless.readlines()
for n in range(len(useless_words)):
    useless_words[n] = useless_words[n].rstrip('\n')
    
# Union on all 3 lists "stop_words".
STOP_WORDS = nltk_stopwords.union(sklearn_stopwords)
#STOP_WORDS = nltk_stopwords.union(sklearn_stopwords).union(useless_words)

#print(STOP_WORDS)

# %%
# Load data that contains series storylines.
df_storylines = pd.read_csv("C:\\Users\\stosc\\Documents\\ESME\\Ingé2_2019-2020\\S2\\UE1\\DataTools\\Projet\series_storylines.csv",
                      header=0, index_col=0)

type(df_storylines)
# Out:
# pandas.core.frame.DataFrame

# %%
# Create dataframe with top 10 series.

df_top_ten = pd.DataFrame(df_storylines.iloc[0:10,0])

# %% [markdown]
# # Clean datas

# %%
# Convert all text to lowercase.
df_storylines["Storyline"] = df_storylines["Storyline"].str.lower()

# %% [markdown]
# def remove_stopwords(story):
#
#     for n in range(len(story)):
#
#         words_storyline = story.iloc[n, 0].split() # Chaque mot de la liste
#
#         # Remove punctuation from a string.
#         remove_punctuation = str.maketrans("","", string.punctuation)
#         for n in range(len(words_storyline)):
#             words_storyline[n] = words_storyline[n].translate(remove_punctuation)
#
#         # Remove words that are in STOP_WORDS.
#         for w in words_storyline :
#             if w in STOP_WORDS:
#                 words_storyline.remove(w)
#
#     return words_storyline

# %%
liste=[]
for n in range(len(df_storylines)):
    
    words_storyline = df_storylines.iloc[n, 0].split() # Chaque mot de la liste
    
    # Remove punctuation from a string.
    remove_punctuation = str.maketrans("","", string.punctuation)
    for n in range(len(words_storyline)):
        words_storyline[n] = words_storyline[n].translate(remove_punctuation)
        liste.append(words_storyline)
type(liste)
# Out:
# list

# %%
def remove_punctuation(story):
    
    """
    
    Remove the puncutation on a word. For exemple "good." : remove the dot from good.
    
    :param story: the dataframe that contains the storyline text.
    :type story: pandas dataframe.
    :return: storyline without the punctuation on the words.
    :rtype: string.
    
    """
    rem_punct = str.maketrans("","", string.punctuation)
    result = story.translate(rem_punct)
    
    return result

# %%
def remove_digits(story):
    
    """
    
    Remove the puncutation on a word. For exemple "good." : remove the dot from good.
    
    :param story: the dataframe that contains the storyline text.
    :type story: pandas dataframe.
    :return: each storyline without digits.
    :rtype: string.
    
    """
    
    remove_digits = str.maketrans("", "", digits)
    result = story.translate(remove_digits)
    
    return result

# %%
df_storylines["Storyline"] = df_storylines["Storyline"].apply(remove_punctuation)
df_storylines["Storyline"] = df_storylines["Storyline"].apply(remove_digits)

# %% [markdown]
# # Analysis

# %% [markdown]
# CountVectorizer
#
# First analysis : find words that have high fequency amongs storyline from all first 100 series of the imdb classement.

# %%
cv = CountVectorizer(stop_words = STOP_WORDS, ngram_range=(1,1), max_features=500)

# %%
# Apply CV on train data

cv.fit(df_storylines["Storyline"])

cv_transform = cv.transform(df_storylines["Storyline"])

new_df_storylines = pd.DataFrame(cv_transform.toarray(), columns=cv.get_feature_names())

new_df_storylines = new_df_storylines.drop('series', axis=1)
new_df_storylines.tail(1)
# Out:
#     aang  acts  adventures  agâh  alchemy  alive  america  animated  \
# 99     0     0           0     0        0      0        0         1
#
#     apartment  arctic  ...  worst  wrong  year  yearold  years  york  \
# 99          0       0  ...      0      0     0        0      0     0
#
#     yorkshire  young  younger  youre
# 99          0      0        0      0
#
# [1 rows x 499 columns]

# %% [raw]
# #Ajouter une colonne total
# new_df_storylines['Total'] = new_df_storylines.sum(axis=1)
#
# #Ajouter une ligne total
# sum_row = new_df_storylines.sum(axis=0) #recuperer la somme des ligne
# df_sum=pd.DataFrame(data=sum_row).T #faire de la somme un dataframe
#
# df_sum=df_sum.reindex(columns=new_df_storylines.columns) #aligner l'index des colonnes de df
# df_sum.index = ['Total'] #changee  l'index de la row_total
#
# df_story= new_df_storylines.append(df_sum) #mettre la somme dans df
# df_story

# %%
word_frequency = new_df_storylines.sum(axis=0).sort_values(ascending=False)
#print(word_frequency)

# %%
plt.figure(figsize=(30, 60))
word_frequency[:300].plot.barh()
plt.title("Distribution of Word frequency (Top 100)")
plt.xlabel("Words")
plt.ylabel("Frequency")
#plt.show()
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# TF-IDF
#
# Count not frequent words of the top 10 serie : why the serie is original ?

# %%
from  sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(lowercase=True, 
                         stop_words=STOP_WORDS, 
                         ngram_range=(1,1), 
                         max_features=2000)

# %%
# Transformer la liste des documents en matrice eparse : tableau de fréquence
csr_mat = tfidf.fit_transform(df_top_ten["Storyline"])
#csr_mat.toarray()

words = tfidf.get_feature_names()

df_tfidf = pd.DataFrame(index=df_top_ten["Storyline"], data=csr_mat.toarray(), columns=words)
df_tfidf
# Out:
#                                                     acclaimed  accompanied  \
# Storyline
#     david attenborough returns in this breathta...   0.000000     0.000000
#     each  minute episode features a global over...   0.000000     0.000000
#     this is the story of e easy company th regi...   0.000000     0.000000
#     when chemistry teacher walter white is diag...   0.000000     0.000000
#     in april  a huge explosion erupted at the c...   0.000000     0.000000
#     set in baltimore this show centers around t...   0.000000     0.091882
#     nearly a generation after the acclaimed blu...   0.137774     0.000000
#     documentary series focusing on the breadth ...   0.000000     0.000000
#     join the heroic quest for knowledge as we s...   0.000000     0.000000
#     in the mythical continent of westeros sever...   0.000000     0.000000
#
#                                                       action   affects  \
# Storyline
#     david attenborough returns in this breathta...  0.000000  0.000000
#     each  minute episode features a global over...  0.000000  0.000000
#     this is the story of e easy company th regi...  0.135739  0.000000
#     when chemistry teacher walter white is diag...  0.000000  0.126755
#     in april  a huge explosion erupted at the c...  0.000000  0.000000
#     set in baltimore this show centers around t...  0.000000  0.000000
#     nearly a generation after the acclaimed blu...  0.000000  0.000000
#     documentary series focusing on the breadth ...  0.000000  0.000000
#     join the heroic quest for knowledge as we s...  0.000000  0.000000
#     in the mythical continent of westeros sever...  0.000000  0.000000
#
#                                                       africa  airborne  \
# Storyline
#     david attenborough returns in this breathta...  0.000000  0.000000
#     each  minute episode features a global over...  0.000000  0.000000
#     this is the story of e easy company th regi...  0.000000  0.135739
#     when chemistry teacher walter white is diag...  0.000000  0.000000
#     in april  a huge explosion erupted at the c...  0.000000  0.000000
#     set in baltimore this show centers around t...  0.000000  0.000000
#     nearly a generation after the acclaimed blu...  0.000000  0.000000
#     documentary series focusing on the breadth ...  0.234523  0.000000
#     join the heroic quest for knowledge as we s...  0.000000  0.000000
#     in the mythical continent of westeros sever...  0.000000  0.000000
#
#                                                      america   ancient  \
# Storyline
#     david attenborough returns in this breathta...  0.000000  0.000000
#     each  minute episode features a global over...  0.000000  0.000000
#     this is the story of e easy company th regi...  0.000000  0.000000
#     when chemistry teacher walter white is diag...  0.000000  0.000000
#     in april  a huge explosion erupted at the c...  0.000000  0.000000
#     set in baltimore this show centers around t...  0.000000  0.000000
#     nearly a generation after the acclaimed blu...  0.000000  0.000000
#     documentary series focusing on the breadth ...  0.234523  0.000000
#     join the heroic quest for knowledge as we s...  0.000000  0.141749
#     in the mythical continent of westeros sever...  0.000000  0.166722
#
#                                                        april    arctic  ...  \
# Storyline                                                               ...
#     david attenborough returns in this breathta...  0.000000  0.000000  ...
#     each  minute episode features a global over...  0.000000  0.000000  ...
#     this is the story of e easy company th regi...  0.000000  0.000000  ...
#     when chemistry teacher walter white is diag...  0.000000  0.000000  ...
#     in april  a huge explosion erupted at the c...  0.215872  0.000000  ...
#     set in baltimore this show centers around t...  0.000000  0.000000  ...
#     nearly a generation after the acclaimed blu...  0.000000  0.000000  ...
#     documentary series focusing on the breadth ...  0.000000  0.234523  ...
#     join the heroic quest for knowledge as we s...  0.000000  0.000000  ...
#     in the mythical continent of westeros sever...  0.000000  0.000000  ...
#
#                                                         wife  wilderness  \
# Storyline
#     david attenborough returns in this breathta...  0.000000    0.000000
#     each  minute episode features a global over...  0.000000    0.000000
#     this is the story of e easy company th regi...  0.000000    0.000000
#     when chemistry teacher walter white is diag...  0.126755    0.000000
#     in april  a huge explosion erupted at the c...  0.000000    0.000000
#     set in baltimore this show centers around t...  0.000000    0.000000
#     nearly a generation after the acclaimed blu...  0.000000    0.000000
#     documentary series focusing on the breadth ...  0.000000    0.234523
#     join the heroic quest for knowledge as we s...  0.000000    0.000000
#     in the mythical continent of westeros sever...  0.000000    0.000000
#
#                                                        women   working  \
# Storyline
#     david attenborough returns in this breathta...  0.000000  0.000000
#     each  minute episode features a global over...  0.000000  0.000000
#     this is the story of e easy company th regi...  0.000000  0.000000
#     when chemistry teacher walter white is diag...  0.000000  0.126755
#     in april  a huge explosion erupted at the c...  0.215872  0.000000
#     set in baltimore this show centers around t...  0.000000  0.000000
#     nearly a generation after the acclaimed blu...  0.000000  0.000000
#     documentary series focusing on the breadth ...  0.000000  0.000000
#     join the heroic quest for knowledge as we s...  0.000000  0.000000
#     in the mythical continent of westeros sever...  0.000000  0.000000
#
#                                                        world  worldrenowned  \
# Storyline
#     david attenborough returns in this breathta...  0.000000       0.000000
#     each  minute episode features a global over...  0.000000       0.000000
#     this is the story of e easy company th regi...  0.100953       0.000000
#     when chemistry teacher walter white is diag...  0.094271       0.000000
#     in april  a huge explosion erupted at the c...  0.000000       0.000000
#     set in baltimore this show centers around t...  0.000000       0.000000
#     nearly a generation after the acclaimed blu...  0.000000       0.000000
#     documentary series focusing on the breadth ...  0.174421       0.000000
#     join the heroic quest for knowledge as we s...  0.000000       0.166746
#     in the mythical continent of westeros sever...  0.000000       0.000000
#
#                                                       worlds     worse  \
# Storyline
#     david attenborough returns in this breathta...  0.000000  0.000000
#     each  minute episode features a global over...  0.000000  0.000000
#     this is the story of e easy company th regi...  0.000000  0.000000
#     when chemistry teacher walter white is diag...  0.000000  0.000000
#     in april  a huge explosion erupted at the c...  0.000000  0.215872
#     set in baltimore this show centers around t...  0.000000  0.000000
#     nearly a generation after the acclaimed blu...  0.117121  0.000000
#     documentary series focusing on the breadth ...  0.000000  0.000000
#     join the heroic quest for knowledge as we s...  0.141749  0.000000
#     in the mythical continent of westeros sever...  0.000000  0.000000
#
#                                                        years      yeti
# Storyline
#     david attenborough returns in this breathta...  0.000000  0.000000
#     each  minute episode features a global over...  0.000000  0.000000
#     this is the story of e easy company th regi...  0.000000  0.000000
#     when chemistry teacher walter white is diag...  0.126755  0.000000
#     in april  a huge explosion erupted at the c...  0.000000  0.000000
#     set in baltimore this show centers around t...  0.000000  0.000000
#     nearly a generation after the acclaimed blu...  0.000000  0.137774
#     documentary series focusing on the breadth ...  0.000000  0.000000
#     join the heroic quest for knowledge as we s...  0.000000  0.000000
#     in the mythical continent of westeros sever...  0.000000  0.000000
#
# [10 rows x 329 columns]

# %%
#Affiche les mots utiles : qui ne sont pas présents dans tous les documents mais présent dans un un seul et apporte une différence
inverse_document_freq = pd.DataFrame({"idf":tfidf.idf_}, 
                                     index=tfidf.get_feature_names())
inverse_document_freq = inverse_document_freq.sort_values(by="idf", ascending=False)

# %%
plt.figure(figsize=(16, 8))
plt.title("Distribution of Inverse document frequency (Top 50)")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.bar(height=inverse_document_freq[:50]['idf'], 
        x=inverse_document_freq[:50].index)
plt.xticks(rotation=90)
plt.show()
